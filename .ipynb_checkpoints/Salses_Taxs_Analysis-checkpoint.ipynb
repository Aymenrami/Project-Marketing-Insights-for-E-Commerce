# %%
import pandas as pd 
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import zscore

# %%
engine = create_engine('mysql+pymysql://root:Aymen@localhost/ecommerce_db')

# %%
# Load data from the database
customersinfo = pd.read_sql('SELECT * FROM customersinfo', engine)
discount_coupon = pd.read_sql('SELECT * FROM discount_coupon', engine)
marketing_spend = pd.read_sql('SELECT * FROM marketing_spend', engine)
Onlin_Sales = pd.read_sql('SELECT * FROM online_sales', engine)
tax_amount = pd.read_sql('SELECT * FROM tax_amount', engine)

df = pd.read_excel(r"C:\Users\Lenovo\Desktop\Project Aymen\Project-Marketing-Insights-for-E-Commerce-Company\E-CO Data\Online_Salse_Transformexlsx.xlsx")

# %%
df
# Out:
#        Transaction_ID Transaction_Date  CustomerID  TypeOfDay  Quarter  \
# 0               16679       2019-01-01       17850  NormalDay        1
# 1               16680       2019-01-01       17850  NormalDay        1
# 2               16681       2019-01-01       17850  NormalDay        1
# 3               16682       2019-01-01       17850  NormalDay        1
# 4               16682       2019-01-01       17850  NormalDay        1
# ...               ...              ...         ...        ...      ...
# 52919           48493       2019-12-31       14410  NormalDay        4
# 52920           48494       2019-12-31       14410  NormalDay        4
# 52921           48495       2019-12-31       14410  NormalDay        4
# 52922           48496       2019-12-31       14600  NormalDay        4
# 52923           48497       2019-12-31       14600  NormalDay        4
#
#       Nom du jour Nom du mois     Product_SKU  \
# 0           mardi     janvier  GGOENEBJ079499
# 1           mardi     janvier  GGOENEBJ079499
# 2           mardi     janvier  GGOEGFKQ020399
# 3           mardi     janvier  GGOEGAAB010516
# 4           mardi     janvier  GGOEGBJL013999
# ...           ...         ...             ...
# 52919       mardi    décembre  GGOENEBB078899
# 52920       mardi    décembre  GGOEGAEB091117
# 52921       mardi    décembre  GGOENEBQ084699
# 52922       mardi    décembre  GGOENEBQ079199
# 52923       mardi    décembre  GGOENEBQ079099
#
#                                      Product_Description Product_Category  \
# 0      Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1      Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2                  Google Laptop and Cell Phone Stickers           Office
# 3      Google Men's 100% Cotton Short Sleeve Hero Tee...          Apparel
# 4                        Google Canvas Tote Natural/Navy             Bags
# ...                                                  ...              ...
# 52919              Nest Cam Indoor Security Camera - USA         Nest-USA
# 52920                            Google Zip Hoodie Black          Apparel
# 52921       Nest Learning Thermostat 3rd Gen-USA - White         Nest-USA
# 52922      Nest Protect Smoke + CO White Wired Alarm-USA         Nest-USA
# 52923    Nest Protect Smoke + CO White Battery Alarm-USA         Nest-USA
#
#        Quantity  Avg_Price  Delivery_Charges  Totale_Benifice Coupon_Status
# 0             1     153.71              6.50           160.21          Used
# 1             1     153.71              6.50           160.21          Used
# 2             1       2.05              6.50             8.55          Used
# 3             5      17.53              6.50            94.15      Not Used
# 4             1      16.50              6.50            23.00          Used
# ...         ...        ...               ...              ...           ...
# 52919         1     121.30              6.50           127.80       Clicked
# 52920         1      48.92              6.50            55.42          Used
# 52921         1     151.88              6.50           158.38          Used
# 52922         5      80.52              6.50           409.10       Clicked
# 52923         4      80.52             19.99           342.07       Clicked
#
# [52924 rows x 15 columns]

# %%
df.shape
# Out:
# (52924, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52924 entries, 0 to 52923
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Transaction_ID       52924 non-null  int64
#  1   Transaction_Date     52924 non-null  datetime64[ns]
#  2   CustomerID           52924 non-null  int64
#  3   TypeOfDay            52924 non-null  object
#  4   Quarter              52924 non-null  int64
#  5   Nom du jour          52924 non-null  object
#  6   Nom du mois          52924 non-null  object
#  7   Product_SKU          52924 non-null  object
#  8   Product_Description  52924 non-null  object
#  9   Product_Category     52924 non-null  object
#  10  Quantity             52924 non-null  int64
#  11  Avg_Price            52924 non-null  float64
#  12  Delivery_Charges     52924 non-null  float64
#  13  Totale_Benifice      52924 non-null  float64
#  14  Coupon_Status        52924 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(4), object(7)
# memory usage: 6.1+ MB

# %%
Statistique_df=df[['Quantity' , 'Avg_Price' , 'Delivery_Charges' , 'Totale_Benifice']].describe().round(2)
Statistique_df
# Out:
#        Quantity  Avg_Price  Delivery_Charges  Totale_Benifice
# count   52924.0   52924.00          52924.00         52924.00
# mean        4.5      52.24             10.52            98.77
# std        20.1      64.01             19.48           166.44
# min         1.0       0.39              0.00             4.12
# 25%         1.0       5.70              6.00            19.59
# 50%         1.0      16.99              6.00            42.89
# 75%         2.0     102.13              6.50           129.27
# max       900.0     355.74            521.36         10518.39

# %%
Most_Category=df[['Product_Category' , 'Quantity']]

# %%
PV_Quantity = Most_Category.groupby('Product_Category')['Quantity'].sum().reset_index(name='Sum_Quantity').sort_values(by='Sum_Quantity' , ascending = False)

# %%
plt.figure(figsize=(5,5))
sns.barplot(x='Sum_Quantity' , y= 'Product_Category' ,data = PV_Quantity)
# Out:
# <Axes: xlabel='Sum_Quantity', ylabel='Product_Category'>

# %%
Delivery_Charge_By_Location=pd.read_sql ("CALL Delivery_Charge_By_Location()"  ,engine)
Delivery_Charge_By_Location.round(2)
# Out:
#         Location  Mean_Of_Delevry
# 0     California            10.72
# 1       New York            10.70
# 2        Chicago            10.51
# 3  Washington DC            10.34
# 4     New Jersey             9.50

# %%
plt.figure(figsize=(4,4.3))
sns.barplot(x= 'Location' , y = 'Mean_Of_Delevry' , data =Delivery_Charge_By_Location)
plt.xticks(rotation =45)
for ind, vl in enumerate(Delivery_Charge_By_Location['Mean_Of_Delevry']):
    plt.text(ind, vl, f'{vl:.2f}', ha='center', va='bottom')

# %%
sales_by_day = df.groupby('Nom du jour')['Quantity'].sum()
sales_by_month = df.groupby('Nom du mois')['Quantity'].sum()

# %%
plt.figure(figsize=(3,3))
sns.histplot(sales_by_day, kde=True)
plt.title('Distribution of Sales by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Total Sales')
plt.show()
plt.figure(figsize=(3,3))
sns.histplot(sales_by_month, kde=True)
plt.title('Distribution of Sales by Month')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.show()

# %%
plt.figure(figsize=(3,3))
stats.probplot(sales_by_day,dist="norm", plot=plt)
plt.title('Q-Q Plot of Sales by Day of the Week')
plt.show()
plt.figure(figsize=(3,3))
stats.probplot(sales_by_month, dist="norm", plot=plt)
plt.title('Q-Q Plot of Sales by Month')
plt.show()

# %%
df['Z_Score'] = zscore(df['Quantity'])
outliers = df[(df['Z_Score'] > 2) | (df['Z_Score'] < -2)]
outliers[['Product_Category' ,'Product_Description', 'Quantity', 'Z_Score']]
# Out:
#            Product_Category                    Product_Description  Quantity  \
# 9                    Office                               Maze Pen        52
# 131                  Office           Pen Pencil & Highlighter Set        57
# 308                  Office          Retractable Ballpoint Pen Red       103
# 317                  Office                Ballpoint LED Light Pen        62
# 318    Notebooks & Journals                    Google RFID Journal        62
# ...                     ...                                    ...       ...
# 52177                Office  Google Laptop and Cell Phone Stickers        51
# 52178                Office                Ballpoint LED Light Pen        51
# 52179                Office           Google Metallic Notebook Set        51
# 52528             Drinkware              Google 22 oz Water Bottle        51
# 52529                Office                Ballpoint LED Light Pen        51
#
#         Z_Score
# 9      2.362770
# 131    2.611470
# 308    4.899513
# 317    2.860171
# 318    2.860171
# ...         ...
# 52177  2.313030
# 52178  2.313030
# 52179  2.313030
# 52528  2.313030
# 52529  2.313030
#
# [899 rows x 4 columns]

# %%
outliers.groupby(['Product_Category','Product_Description']).agg({'Quantity'  : 'size'})
# Out:
#                                                         Quantity
# Product_Category Product_Description
# Accessories      Android Large Removable Sticker Sheet         2
#                  Android Small Removable Sticker Sheet         2
#                  Emoji Sticker Sheet                           1
#                  Google Emoji Sticker Pack                     1
# Apparel          Android Baby Esssentials Set                  3
# ...                                                          ...
# Office           Switch Tone Color Crayon Pen                  4
#                  YouTube Custom Decals                         9
#                  YouTube Leatherette Notebook Combo            6
#                  YouTube Notebook and Pen Set                  3
# Waze             Waze Mood Original Window Decal               1
#
# [108 rows x 1 columns]

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x=range(len(df)), y='Z_Score', hue='Z_Score', palette='coolwarm' , s = 100)
plt.axhline(y=2, color='red', linestyle='--')
plt.axhline(y=-2, color='red', linestyle='--')
plt.xlabel('Index')
plt.ylabel('Z-Score')
plt.title('Scatter Plot of Z-Scores for Product Sales')
plt.show()

# %%
delevry_chayrg_by_product = df.groupby('Product_Category')['Delivery_Charges'].mean().round(2).reset_index(name='mean of delivry').sort_values(by = 'mean of delivry' , ascending = False
)

# %%
delevry_chayrg_by_product
# Out:
#         Product_Category  mean of delivry
# 9                 Google            26.73
# 17  Notebooks & Journals            21.11
# 11            Housewares            16.86
# 18                Office            15.12
# 6              Drinkware            14.39
# 12             Lifestyle            13.98
# 4                   Bags            13.63
# 5                Bottles            13.08
# 3              Backpacks            13.07
# 0            Accessories            11.91
# 7                    Fun            11.75
# 13             More Bags            10.78
# 2                Apparel             9.76
# 10              Headgear             9.68
# 19                  Waze             9.66
# 15           Nest-Canada             9.16
# 1                Android             8.53
# 14                  Nest             7.32
# 16              Nest-USA             7.11
# 8             Gift Cards             0.00

# %%
sns.barplot(x='mean of delivry' , y = 'Product_Category' , data =delevry_chayrg_by_product )
# Out:
# <Axes: xlabel='mean of delivry', ylabel='Product_Category'>

# %%
xxx = df.groupby('Product_Category')[['Delivery_Charges' , 'Quantity']].agg({'Delivery_Charges' : 'mean' , 'Quantity' : 'sum'}).round(2).sort_values(by = 'Quantity' , ascending = False)
xxx
# Out:
#                       Delivery_Charges  Quantity
# Product_Category
# Office                           15.12     88383
# Apparel                           9.76     32438
# Drinkware                        14.39     30501
# Lifestyle                        13.98     24881
# Nest-USA                          7.11     21430
# Bags                             13.63     15273
# Notebooks & Journals             21.11      9556
# Headgear                          9.68      3533
# Nest                              7.32      2837
# Housewares                       16.86      2484
# Bottles                          13.08      2090
# Waze                              9.66      1144
# Accessories                      11.91      1097
# Fun                              11.75       834
# Google                           26.73       575
# Nest-Canada                       9.16       469
# Gift Cards                        0.00       206
# More Bags                        10.78       144
# Backpacks                        13.07       113
# Android                           8.53        45

# %%
Quantity_Dilivery_charge_corr = xxx[['Delivery_Charges' , 'Quantity']]

# %%
Quantity_Dilivery_charge_corr.corr()
# Out:
#                   Delivery_Charges  Quantity
# Delivery_Charges          1.000000  0.129065
# Quantity                  0.129065  1.000000

# %%
sns.scatterplot(x='Quantity' , y='Delivery_Charges' , data = Quantity_Dilivery_charge_corr )
# Out:
# <Axes: xlabel='Quantity', ylabel='Delivery_Charges'>

# %%
pd.read_sql("call Get_Customers_Using_Coupons()" , engine )
# Out:
#       CustomerID  How_Many_Coupons Coupon_Status
# 0          12748               252          Used
# 1          14606               219          Used
# 2          17841               208          Used
# 3          15311               189          Used
# 4          14911               178          Used
# ...          ...               ...           ...
# 1369       17707                 1          Used
# 1370       17929                 1          Used
# 1371       17949                 1          Used
# 1372       18193                 1          Used
# 1373       18233                 1          Used
#
# [1374 rows x 3 columns]

# %%
df.groupby('Coupon_Status')['Transaction_ID'].size()
# Out:
# Coupon_Status
# Clicked     26926
# Not Used     8094
# Used        17904
# Name: Transaction_ID, dtype: int64

# %%
bins = [0,12,24,36,48,100] 
labels = ['<1 year', '1-2 years', '2-3 years', '3-4 years' , '4+ years']
customersinfo['Tenure_Group'] = pd.cut(customersinfo['Tenure_Months'], bins=bins, labels=labels, right=False)

# %%
customersinfo
# Out:
#       CustomerID Gender    Location  Tenure_Months Tenure_Group
# 0          12346      F    New York             31    2-3 years
# 1          12347      M    New York             20    1-2 years
# 2          12348      M  California             39    3-4 years
# 3          12350      M  California             25    2-3 years
# 4          12356      F     Chicago             31    2-3 years
# ...          ...    ...         ...            ...          ...
# 1463       18259      F  California              5      <1 year
# 1464       18260      M    New York             43    3-4 years
# 1465       18269      M     Chicago             25    2-3 years
# 1466       18277      F     Chicago             47    3-4 years
# 1467       18283      F  New Jersey             36    3-4 years
#
# [1468 rows x 5 columns]

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=customersinfo, x='Tenure_Group', hue='Tenure_Group')
plt.title('Distribution of Customers by Tenure')
plt.xlabel('Tenure Group')
plt.ylabel('Number of Customers')
plt.show()

# %%
df_sales=df
df_customers=customersinfo
merged_df = pd.merge(df_sales, df_customers, on='CustomerID', how='inner')

# %%
merged_df=merged_df[['Quantity' , 'Tenure_Group_y']]

# %%
tenure_stats = merged_df.groupby('Tenure_Group_y')['Quantity'].agg(['mean' , 'std']).round(2).reset_index()
tenure_stats
# Out:
#   Tenure_Group_y  mean    std
# 0        <1 year  4.45  20.59
# 1      1-2 years  4.13  14.06
# 2      2-3 years  5.01  22.69
# 3      3-4 years  4.28  20.94
# 4       4+ years  4.41  21.37

# %%
plt.figure(figsize=(4, 4))
sns.lineplot(data=tenure_stats, x='Tenure_Group_y', y='mean', marker='o',errorbar=None)
plt.fill_between(tenure_stats['Tenure_Group_y'], 
                 tenure_stats['mean'] - tenure_stats['std'], 
                 tenure_stats['mean'] + tenure_stats['std'], 
                 color='b', alpha=0.2, label='Standard Deviation')
plt.xlabel('Tenure Group')
plt.ylabel('Mean Quantity')
plt.title('Mean Quantity of Purchases by Tenure Group')
plt.show()

# %%
Category_With_Tax = pd.read_sql("call Get_Category_With_Highest_Tax_Rate" , engine)
Category_With_Tax
# Out:
#         Product_Category  SumQuantity  GST_Percentage
# 0                Apparel      32438.0            18.0
# 1                   Bags      15273.0            18.0
# 2              Drinkware      30501.0            18.0
# 3              Lifestyle      24881.0            18.0
# 4                   Waze       1144.0            18.0
# 5                    Fun        834.0            18.0
# 6              More Bags        144.0            18.0
# 7             Housewares       2484.0            12.0
# 8               Nest-USA      21430.0            10.0
# 9                 Office      88383.0            10.0
# 10           Nest-Canada        469.0            10.0
# 11             Backpacks        113.0            10.0
# 12                Google        575.0            10.0
# 13               Android         45.0            10.0
# 14           Accessories       1097.0            10.0
# 15  Notebooks & Journals       9556.0             5.0
# 16              Headgear       3533.0             5.0
# 17               Bottles       2090.0             5.0
# 18            Gift Cards        206.0             5.0
# 19                  Nest       2837.0             5.0

# %%
sns.barplot(x='GST_Percentage' , y='Product_Category' , data= Category_With_Tax)
# Out:
# <Axes: xlabel='GST_Percentage', ylabel='Product_Category'>
